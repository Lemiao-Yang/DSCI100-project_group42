# %% [markdown]
# # DSCI Group Project -- Group 42

# %%
library(tidyverse)
library(dplyr)
library(tidymodels)
library(themis)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use suppressPackageStartupMessages() to eliminate package startup messages

# %%
players <- read_csv("players.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Research Question

# %% [markdown]
# ### How do player characteristics like total hours played, experience level, age, and gender predict the likelihood of newsletter subscription?

# %% [markdown]
# Before applying the K-NN algorithm, we first need to set a random seed for reproducibility and clean our dataset.
#
# We will transform the `subscribe` and `experience` variables into factors since they are categorical. We will also remove any irrelevant variables that won't be used in the model. Lastly, we will remove observations with missing values to ensure our dataset is complete and ready for analysis. The cleaned dataset will be stored in the `clean_players` variable!

# %%
set.seed(6666)

clean_players <- players |>
    mutate(subscribe = as.factor(subscribe),
           experience = as.factor(experience)) |>
    select(-hashedEmail, -gender, -name) |>
    filter(!is.na(Age)) |>
    filter(!is.na(experience)) |>
    filter(!is.na(subscribe))

head(clean_players)
# Out:
#   experience subscribe played_hours Age
# 1 Pro        TRUE      30.3          9
# 2 Veteran    TRUE       3.8         17
# 3 Veteran    FALSE      0.0         17
# 4 Amateur    TRUE       0.7         21
# 5 Regular    TRUE       0.1         21
# 6 Amateur    TRUE       0.0         17

# %% [markdown]
# #### Setting Up Training and Testing Data

# %% [markdown]
# To start our K-NN classification, we use the `initial_split` function to split our cleaned dataset. 70% of the data will be used for training our model, while the remaining 30% will be used for testing it. We do this because we want to train the algorithm with our data, but still be able to test using the same data.

# %%
players_split <- initial_split(clean_players, prop = 0.7, strata = subscribe)
players_train <- training(players_split)
players_test <- testing(players_split)

# %% [markdown]
# #### Creating a Recipe and Model

# %% [markdown]
# Our next step is to create a recipe. A recipe defines the preprocessing steps we want to apply to our dataset before executing the analysis. In this case, our target variable is subscribe, and we will use `Age`, `played_hours`, and `experience` as predictor variables. To ensure that no single variable dominates the model due to scale differences, we will scale and center *Age* and *played_hours*. To help our model, we're also going to upsample the *subscribe* variable. This step will prevent the model from being biased towards the majority class (i.e. players who did subscribe).
#
# Finally, we will use the `nearest_neighbors` function to specify that our analysis will use K-NN classification!"

# %%
players_recipe <- recipe(subscribe ~ ., data = players_train) |>
    step_scale(Age, played_hours) |>
    step_center(Age, played_hours) |>
    step_upsample(subscribe, over_ratio = 1, skip = TRUE)
players_recipe

knn_spec_tuned <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
    set_engine("kknn") |>
    set_mode("classification")
knn_spec_tuned
# Out:
# ── Recipe ──────────────────────────────────────────────────────────────────────
#
#
#
# ── Inputs
#
# Number of variables by role
#
# outcome:   1
# predictor: 3
#
#
#
# ── Operations
#
# • Scaling for: Age and played_hours
#
# • Centering for: Age and played_hours
#
# • Up-sampling based on: subscribe
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %% [markdown]
# #### Using 5 Fold Cross Validation and Train the Model

# %% [markdown]
# Now, we will set up 5-fold cross-validation for the training set. Cross-validation will evaluate the performance of each model with different k-values by training on a portion of the data and testing it on the remaining part. This process is repeated multiple times to obtain an average result. This step provides a more reliable estimate of our algorithm's ability to predict the `subscribe` variable through its multiple tests.
#
# We're going to define our grid by giving a large range for the neighbors parameter in our K-NN model.
#
# Finally, we're going to set up our workflow. We want to combine our recipe, our type of model, and the cross-validation.

# %%
players_vfold <- vfold_cv(players_train, v = 5, strata = subscribe)
k_vals <- tibble(neighbors = seq(from = 1, to = 100, by = 1))

knn_tuned_fit <- workflow() |>
    add_recipe(players_recipe) |>
    add_model(knn_spec_tuned) |>
    tune_grid(resamples = players_vfold, grid = k_vals) |>
    collect_metrics()
knn_tuned_fit
# Out:
#     neighbors .metric  .estimator mean      n std_err    .config
# 1    1        accuracy binary     0.5643875 5 0.04428894 Preprocessor1_Model001
# 2    1        roc_auc  binary     0.5452068 5 0.06436307 Preprocessor1_Model001
# 3    2        accuracy binary     0.5347578 5 0.05192225 Preprocessor1_Model002
# 4    2        roc_auc  binary     0.5314286 5 0.06989788 Preprocessor1_Model002
# 5    3        accuracy binary     0.4746235 5 0.04997324 Preprocessor1_Model003
# 6    3        roc_auc  binary     0.5080169 5 0.07381533 Preprocessor1_Model003
# 7    4        accuracy binary     0.4820309 5 0.05077001 Preprocessor1_Model004
# 8    4        roc_auc  binary     0.4862500 5 0.08296925 Preprocessor1_Model004
# 9    5        accuracy binary     0.4751933 5 0.05181377 Preprocessor1_Model005
# 10   5        roc_auc  binary     0.4972838 5 0.09654577 Preprocessor1_Model005
# 11   6        accuracy binary     0.4754782 5 0.05781960 Preprocessor1_Model006
# 12   6        roc_auc  binary     0.5057989 5 0.09367049 Preprocessor1_Model006
# 13   7        accuracy binary     0.5128002 5 0.05858569 Preprocessor1_Model007
# 14   7        roc_auc  binary     0.5043797 5 0.08753307 Preprocessor1_Model007
# 15   8        accuracy binary     0.5128002 5 0.06523288 Preprocessor1_Model008
# 16   8        roc_auc  binary     0.5187876 5 0.09770722 Preprocessor1_Model008
# 17   9        accuracy binary     0.5133293 5 0.05066842 Preprocessor1_Model009
# 18   9        roc_auc  binary     0.5137077 5 0.09955905 Preprocessor1_Model009
# 19  10        accuracy binary     0.5130444 5 0.04517368 Preprocessor1_Model010
# 20  10        roc_auc  binary     0.5202068 5 0.09396739 Preprocessor1_Model010
# 21  11        accuracy binary     0.5800366 5 0.05924317 Preprocessor1_Model011
# 22  11        roc_auc  binary     0.5296852 5 0.09796460 Preprocessor1_Model011
# 23  12        accuracy binary     0.5803012 5 0.06510892 Preprocessor1_Model012
# 24  12        roc_auc  binary     0.5312547 5 0.09029495 Preprocessor1_Model012
# 25  13        accuracy binary     0.5797314 5 0.05986831 Preprocessor1_Model013
# 26  13        roc_auc  binary     0.5422885 5 0.07983627 Preprocessor1_Model013
# 27  14        accuracy binary     0.5654457 5 0.06977112 Preprocessor1_Model014
# 28  14        roc_auc  binary     0.5160291 5 0.07804238 Preprocessor1_Model014
# 29  15        accuracy binary     0.5487383 5 0.02147997 Preprocessor1_Model015
# 30  15        roc_auc  binary     0.5309586 5 0.05967368 Preprocessor1_Model015
# ⋮   ⋮         ⋮        ⋮          ⋮         ⋮ ⋮          ⋮
# 171  86       accuracy binary     0.4350834 5 0.05860099 Preprocessor1_Model086
# 172  86       roc_auc  binary     0.4001833 5 0.06012450 Preprocessor1_Model086
# 173  87       accuracy binary     0.3826618 5 0.06259468 Preprocessor1_Model087
# 174  87       roc_auc  binary     0.3923167 5 0.05990055 Preprocessor1_Model087
# 175  88       accuracy binary     0.3755189 5 0.05740163 Preprocessor1_Model088
# 176  88       roc_auc  binary     0.3843233 5 0.06508578 Preprocessor1_Model088
# 177  89       accuracy binary     0.4347985 5 0.05224463 Preprocessor1_Model089
# 178  89       roc_auc  binary     0.3971194 5 0.07200064 Preprocessor1_Model089
# 179  90       accuracy binary     0.4347985 5 0.04954950 Preprocessor1_Model090
# 180  90       roc_auc  binary     0.3997979 5 0.07626544 Preprocessor1_Model090
# 181  91       accuracy binary     0.4564510 5 0.07525646 Preprocessor1_Model091
# 182  91       roc_auc  binary     0.4115461 5 0.08075499 Preprocessor1_Model091
# 183  92       accuracy binary     0.4416361 5 0.07175587 Preprocessor1_Model092
# 184  92       roc_auc  binary     0.4055357 5 0.08068801 Preprocessor1_Model092
# 185  93       accuracy binary     0.4487790 5 0.08053890 Preprocessor1_Model093
# 186  93       roc_auc  binary     0.4208506 5 0.07779914 Preprocessor1_Model093
# 187  94       accuracy binary     0.4487790 5 0.08053890 Preprocessor1_Model094
# 188  94       roc_auc  binary     0.4408224 5 0.08279517 Preprocessor1_Model094
# 189  95       accuracy binary     0.4857957 5 0.09113089 Preprocessor1_Model095
# 190  95       roc_auc  binary     0.4635855 5 0.08316055 Preprocessor1_Model095
# 191  96       accuracy binary     0.4709809 5 0.09100509 Preprocessor1_Model096
# 192  96       roc_auc  binary     0.4690977 5 0.08898141 Preprocessor1_Model096
# 193  97       accuracy binary     0.4715507 5 0.08700195 Preprocessor1_Model097
# 194  97       roc_auc  binary     0.4635197 5 0.09347623 Preprocessor1_Model097
# 195  98       accuracy binary     0.4860806 5 0.08949673 Preprocessor1_Model098
# 196  98       roc_auc  binary     0.4813581 5 0.09160404 Preprocessor1_Model098
# 197  99       accuracy binary     0.5311355 5 0.07092783 Preprocessor1_Model099
# 198  99       roc_auc  binary     0.4964051 5 0.08784118 Preprocessor1_Model099
# 199 100       accuracy binary     0.5165853 5 0.07093846 Preprocessor1_Model100
# 200 100       roc_auc  binary     0.4988487 5 0.08631632 Preprocessor1_Model100

# %% [markdown]
# #### Visualize Accuracy with Different K Values

# %% [markdown]
# Now that we've fully trained our model, it's time to visualize the accuracy for each value of k (number of neighbors). To do so, we want to create a plot that visualizes the relationship between k and its accuracy.

# %%
# Filters and selects only rows that are accuracy metric
accuracy <- knn_tuned_fit |>
    filter(.metric == "accuracy")

accuracy_plot <- accuracy |>
    ggplot(aes(x = neighbors, y = mean)) +
    geom_point() +
    labs(x = "Number of Neighbors",
         y = "Mean Value of Accuracy") +
    ggtitle("Figure 1: The Relationship between Number of Neighbors (k) and Accuracy") +
    theme(text = element_text(size = 11))
accuracy_plot
# Out:
# plot without title

# %% [markdown]
# #### Find the Best K and Fitting it in Training Data

# %% [markdown]
# From our visual, we can use the function `slice_max` to find the number of k-neighbors with the highest accuracy. This will also allow us to know the optimal number of neighbours to use in our final model, and we will name this `best_k`.
#
# With `best_k`, we will specify our optimal model! We'll create our final workflow, which again, will combine all of our previous steps — now with our `best_k`!

# %%
# Finding the best number of neighbors for our model
best_k <- accuracy |>
    slice_max(mean) |>
    pull(neighbors)
best_k

# Optimizing model with new value of k
knn_spec_best <- nearest_neighbor(weight_func = "rectangular", neighbor = best_k) |>
    set_engine("kknn") |>
    set_mode("classification")

# Our final workflow!
knn_best_fit <- workflow() |>
    add_recipe(players_recipe) |>
    add_model(knn_spec_best) |>
    fit(players_test)
# Out:
# [1] 67

# %% [markdown]
# #### Predict Using Testing Data

# %% [markdown]
# After training the K-NN model with the optimal number of neighbors, We are going to use the test dataset to make predictions on the `subscribe` variable. We're going to evaluate the model’s performance using two metrics: accuracy and kappa.

# %%
subscribe_predictions <- predict(knn_best_fit, players_test) |>
    bind_cols(players_test)

subscribe_metrics <- subscribe_predictions |>
    metrics(truth = subscribe, estimate = .pred_class)

subscribe_metrics
subscribe_predictions
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.7796610
# 2 kap      binary     0.3230362
#    .pred_class experience subscribe played_hours Age
# 1  TRUE        Veteran    FALSE       0.0        17
# 2  TRUE        Amateur    FALSE       0.0        21
# 3  TRUE        Pro        TRUE        0.0        17
# 4  TRUE        Amateur    TRUE        0.2        22
# 5  TRUE        Veteran    TRUE        0.0        17
# 6  FALSE       Regular    TRUE        0.3        58
# 7  TRUE        Amateur    FALSE       0.1        17
# 8  TRUE        Beginner   TRUE        0.0        17
# 9  TRUE        Amateur    TRUE        1.8        23
# 10 TRUE        Veteran    TRUE        0.1        21
# 11 TRUE        Veteran    TRUE        0.4        20
# 12 TRUE        Amateur    TRUE        0.2        17
# 13 TRUE        Veteran    TRUE        0.1        17
# 14 TRUE        Beginner   FALSE       0.0        24
# 15 TRUE        Regular    TRUE      218.1        20
# 16 TRUE        Amateur    TRUE        0.2        27
# 17 TRUE        Amateur    TRUE        2.9        11
# 18 TRUE        Regular    TRUE        0.0        17
# 19 TRUE        Amateur    TRUE        0.1        23
# 20 TRUE        Veteran    TRUE        0.1        21
# 21 TRUE        Regular    TRUE        0.2        14
# 22 TRUE        Amateur    TRUE       53.9        17
# 23 TRUE        Amateur    TRUE        3.5        21
# 24 TRUE        Regular    TRUE        0.0        17
# 25 TRUE        Amateur    TRUE        0.0        26
# 26 TRUE        Veteran    TRUE        1.0        17
# 27 TRUE        Amateur    FALSE       0.0        21
# 28 TRUE        Amateur    FALSE       0.0        23
# 29 TRUE        Beginner   TRUE        0.0        23
# 30 TRUE        Amateur    TRUE      150.0        16
# 31 TRUE        Pro        TRUE        1.2        17
# 32 TRUE        Beginner   TRUE        0.8        22
# 33 TRUE        Amateur    TRUE        0.0        20
# 34 TRUE        Veteran    TRUE        0.0        24
# 35 TRUE        Beginner   TRUE        1.0        17
# 36 TRUE        Veteran    FALSE       0.0        20
# 37 FALSE       Veteran    FALSE       0.0        46
# 38 TRUE        Amateur    TRUE       56.1        23
# 39 TRUE        Regular    FALSE       0.1        17
# 40 TRUE        Beginner   TRUE        1.1        20
# 41 TRUE        Regular    TRUE        0.0        20
# 42 TRUE        Beginner   TRUE       23.7        24
# 43 FALSE       Amateur    FALSE       0.1        45
# 44 TRUE        Beginner   TRUE        0.0        22
# 45 TRUE        Beginner   TRUE        0.0        24
# 46 TRUE        Regular    TRUE        0.5        20
# 47 FALSE       Amateur    FALSE       1.0        26
# 48 TRUE        Pro        FALSE       0.4        21
# 49 FALSE       Beginner   FALSE       1.8        32
# 50 TRUE        Veteran    TRUE        0.0        20
# 51 TRUE        Veteran    TRUE        0.0        17
# 52 TRUE        Amateur    TRUE        0.8        22
# 53 TRUE        Amateur    TRUE       32.0        22
# 54 TRUE        Pro        FALSE       1.7        17
# 55 FALSE       Veteran    TRUE        0.1        44
# 56 TRUE        Beginner   TRUE        0.0        17
# 57 TRUE        Amateur    TRUE        0.0        17
# 58 FALSE       Amateur    FALSE       0.0        57
# 59 TRUE        Amateur    FALSE       2.3        17

# %% [markdown]
# **The model achieves an accuracy of 77.97%**, meaning it correctly predicts the subscription status of players about 78% of the time.
#
# These results suggest that the model performs well, but there may still be room for improvement in terms of agreement between predicted and true outcomes.
